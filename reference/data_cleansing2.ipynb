# %%
import pandas as pd

# %%
df = pd.read_csv('./train_pothole1.csv')
lst= list(df['path'])
df
# Out:
#     Unnamed: 0                            path  width  height  label  \
# 0         2976         ./images/1_1000/511.jpg   1920    1080      9
# 1         2977         ./images/1_1000/511.jpg   1920    1080      9
# 2         8703     ./images/1001_2000/1845.jpg   1920    1080      9
# 3         9127     ./images/1001_2000/1924.jpg   1920    1080      9
# 4         9200     ./images/1001_2000/1952.jpg   1920    1080      9
# ..         ...                             ...    ...     ...    ...
# 84      113867  ./images/28001_29000/28339.jpg   1920    1080      9
# 85      113868  ./images/28001_29000/28339.jpg   1920    1080      9
# 86      115935  ./images/28001_29000/28861.jpg   1920    1080      9
# 87      116413  ./images/28001_29000/28951.jpg   1920    1080      9
# 88      118915  ./images/29001_30000/29638.jpg   1920    1080      9
#
#               x           y           w          h
# 0   1361.945996  953.269770   63.439024  77.530650
# ...

# %%
for i, path in enumerate(lst, 1):
    copyfile(''+path, './data_pothole')
