# %%
import pandas as pd

# %%
# dataset 3
df = pd.read_csv('./df.csv')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1                             path            x  \
# 0              0             0       ./data_pothole/ds1_511.jpg  1361.945996
# 1              1             1       ./data_pothole/ds1_511.jpg   987.311850
# 2              2             2      ./data_pothole/ds1_1845.jpg  1088.784657
# 3              3             3      ./data_pothole/ds1_1924.jpg   814.868102
# 4              4             4      ./data_pothole/ds1_1952.jpg  1375.621803
# ...          ...           ...                              ...          ...
# 4215        4216          3891  ./data_pothole/ds4_G0348187.jpg   242.000000
# 4216        4217          3892  ./data_pothole/ds4_G0398363.jpg  2674.000000
# 4217        4218          3893  ./data_pothole/ds4_G0398363.jpg  1902.000000
# 4218        4219          3894  ./data_pothole/ds4_G0398363.jpg  1898.000000
# 4219        4220          3895  ./data_pothole/ds4_G0449113.jpg  2214.000000
#
#                 y           w          h
# 0      953.269770   63.439024  77.530650
# 1      924.494335   89.149211  42.632578
# 2      792.205742   60.434724  27.698565
# 3      837.851675   77.662180  16.502392
# 4      892.110048  138.819650  56.980861
# ...           ...         ...        ...
# 4215  1642.000000  156.000000  42.000000
# 4216  1722.000000  156.000000  44.000000
# 4217  1614.000000  118.000000  52.000000
# 4218  1550.000000   74.000000  30.000000
# 4219  1626.000000  158.000000  80.000000
#
# [4220 rows x 7 columns]

# %%
df['path'].values
# Out:
# array(['./data_pothole/ds1_511.jpg', './data_pothole/ds1_511.jpg',
#        './data_pothole/ds1_1845.jpg', ...,
#        './data_pothole/ds4_G0398363.jpg',
#        './data_pothole/ds4_G0398363.jpg',
#        './data_pothole/ds4_G0449113.jpg'], dtype=object)

# %%
len(df['path'].values)
# Out:
# 4220

# %%
df['path'].unique()
# Out:
# array(['./data_pothole/ds1_511.jpg', './data_pothole/ds1_1845.jpg',
#        './data_pothole/ds1_1924.jpg', ...,
#        './data_pothole/ds4_G0348187.jpg',
#        './data_pothole/ds4_G0398363.jpg',
#        './data_pothole/ds4_G0449113.jpg'], dtype=object)

# %%
len(df['path'].unique())
# Out:
# 1400

# %%
for i, path in enumerate(lst, 0):
    file_name1 = lst[i].split('.')[1].strip()
    name_a = file_name1.split('/')[2].strip()
    
    file_name2 = lst[i].split('=')[1].strip()
    copyfile(path, './temp/{}'.format(name_a+file_name2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_19036/3715938739.py in <module>
#       4
#       5     file_name2 = lst[i].split('=')[1].strip()
# ----> 6     copyfile(path, './temp/{}'.format(file_name1+file_name2))
#
# ~/anaconda3/envs/skku/lib/python3.9/shutil.py in copyfile(src, dst, follow_symlinks)
#     263     else:
#     264         try:
# --> 265             with open(src, 'rb') as fsrc, open(dst, 'wb') as fdst:
#     266                 # macOS
#     267                 if _HAS_FCOPYFILE:
#
# FileNotFoundError: [Errno 2] No such file or directory: './temp//data_pothole/ds3_GH010227196.jpg'

# %%
temp=[]
for i, path in enumerate(lst, 0):
    file_name = lst[i].split('.')[1].strip()
    temp.append(file_name)
    
temp
# Out:
# ['/data_pothole/ds3_GH010227',
#  '/data_pothole/ds3_GH020010',
#  '/data_pothole/ds3_GH020106',
#  '/data_pothole/ds3_GH020164',
#  '/data_pothole/ds3_GH020167',
#  '/data_pothole/ds3_GH030012',
#  '/data_pothole/ds3_GH030012',
#  '/data_pothole/ds3_GH030093',
#  '/data_pothole/ds3_GH030100',
#  '/data_pothole/ds3_GH030100',
#  '/data_pothole/ds3_GH030100',
#  '/data_pothole/ds3_GH030100',
#  '/data_pothole/ds3_GH030100',
#  '/data_pothole/ds3_GH030100',
#  '/data_pothole/ds3_GH030167',
#  '/data_pothole/ds3_GH030221',
#  '/data_pothole/ds3_GH030316',
#  '/data_pothole/ds3_GH040010',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040012',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040167',
#  '/data_pothole/ds3_GH040227',
#  '/data_pothole/ds3_GH040227',
#  '/data_pothole/ds3_GH040239',
#  '/data_pothole/ds3_GH040239',
#  '/data_pothole/ds3_GH040385',
#  '/data_pothole/ds3_GH040385',
#  '/data_pothole/ds3_GH040389',
#  '/data_pothole/ds3_GH040389',
#  '/data_pothole/ds3_GH040389',
#  '/data_pothole/ds3_GH040389',
#  '/data_pothole/ds3_GH040389',
#  '/data_pothole/ds3_GH040389',
#  '/data_pothole/ds3_GH040389',
#  '/data_pothole/ds3_GH040390',
#  '/data_pothole/ds3_GH050007',
#  '/data_pothole/ds3_GH050024',
#  '/data_pothole/ds3_GH050024',
#  '/data_pothole/ds3_GH050094',
#  '/data_pothole/ds3_GH050094',
#  '/data_pothole/ds3_GH050094',
#  '/data_pothole/ds3_GH050167',
#  '/data_pothole/ds3_GH050167',
#  '/data_pothole/ds3_GH050167',
#  '/data_pothole/ds3_GH050239',
#  '/data_pothole/ds3_GH050239',
#  '/data_pothole/ds3_GH050390',
#  '/data_pothole/ds3_GH060010',
#  '/data_pothole/ds3_GH060012',
#  '/data_pothole/ds3_GH060012',
#  '/data_pothole/ds3_GH060012',
#  '/data_pothole/ds3_GH060012',
#  '/data_pothole/ds3_GH060012',
#  '/data_pothole/ds3_GH060012',
#  '/data_pothole/ds3_GH060012',
#  '/data_pothole/ds3_GH060164',
#  '/data_pothole/ds3_GH060168',
#  '/data_pothole/ds3_GH060229',
#  '/data_pothole/ds3_GH060229',
#  '/data_pothole/ds3_GH060229',
#  '/data_pothole/ds3_GH060229',
#  '/data_pothole/ds3_GH060229',
#  '/data_pothole/ds3_GH060229',
#  '/data_pothole/ds3_GH060229',
#  '/data_pothole/ds3_GH060239',
#  '/data_pothole/ds3_GH060239',
#  '/data_pothole/ds3_GH060386',
#  '/data_pothole/ds3_GH060386',
#  '/data_pothole/ds3_GH070094',
#  '/data_pothole/ds3_GH070094',
#  '/data_pothole/ds3_GH070094',
#  '/data_pothole/ds3_GH070094',
#  '/data_pothole/ds3_GH070229',
#  '/data_pothole/ds3_GH070229',
#  '/data_pothole/ds3_GH070229',
#  '/data_pothole/ds3_GH070229',
#  '/data_pothole/ds3_GH070234',
#  '/data_pothole/ds3_GH070239',
#  '/data_pothole/ds3_GH070239',
#  '/data_pothole/ds3_GH080229',
#  '/data_pothole/ds3_GH080229',
#  '/data_pothole/ds3_GH080234',
#  '/data_pothole/ds3_GH080234',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090010',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH090234',
#  '/data_pothole/ds3_GH100010',
#  '/data_pothole/ds3_GH100010']

# %%
lst =temp
temp=[]
for i, path in enumerate(lst, 0):
    file_name = lst[i].split('/')[2].strip()
    temp.append(file_name)
    
temp
# Out:
# ['ds3_GH010227',
#  'ds3_GH020010',
#  'ds3_GH020106',
#  'ds3_GH020164',
#  'ds3_GH020167',
#  'ds3_GH030012',
#  'ds3_GH030012',
#  'ds3_GH030093',
#  'ds3_GH030100',
#  'ds3_GH030100',
#  'ds3_GH030100',
#  'ds3_GH030100',
#  'ds3_GH030100',
#  'ds3_GH030100',
#  'ds3_GH030167',
#  'ds3_GH030221',
#  'ds3_GH030316',
#  'ds3_GH040010',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040012',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040167',
#  'ds3_GH040227',
#  'ds3_GH040227',
#  'ds3_GH040239',
#  'ds3_GH040239',
#  'ds3_GH040385',
#  'ds3_GH040385',
#  'ds3_GH040389',
#  'ds3_GH040389',
#  'ds3_GH040389',
#  'ds3_GH040389',
#  'ds3_GH040389',
#  'ds3_GH040389',
#  'ds3_GH040389',
#  'ds3_GH040390',
#  'ds3_GH050007',
#  'ds3_GH050024',
#  'ds3_GH050024',
#  'ds3_GH050094',
#  'ds3_GH050094',
#  'ds3_GH050094',
#  'ds3_GH050167',
#  'ds3_GH050167',
#  'ds3_GH050167',
#  'ds3_GH050239',
#  'ds3_GH050239',
#  'ds3_GH050390',
#  'ds3_GH060010',
#  'ds3_GH060012',
#  'ds3_GH060012',
#  'ds3_GH060012',
#  'ds3_GH060012',
#  'ds3_GH060012',
#  'ds3_GH060012',
#  'ds3_GH060012',
#  'ds3_GH060164',
#  'ds3_GH060168',
#  'ds3_GH060229',
#  'ds3_GH060229',
#  'ds3_GH060229',
#  'ds3_GH060229',
#  'ds3_GH060229',
#  'ds3_GH060229',
#  'ds3_GH060229',
#  'ds3_GH060239',
#  'ds3_GH060239',
#  'ds3_GH060386',
#  'ds3_GH060386',
#  'ds3_GH070094',
#  'ds3_GH070094',
#  'ds3_GH070094',
#  'ds3_GH070094',
#  'ds3_GH070229',
#  'ds3_GH070229',
#  'ds3_GH070229',
#  'ds3_GH070229',
#  'ds3_GH070234',
#  'ds3_GH070239',
#  'ds3_GH070239',
#  'ds3_GH080229',
#  'ds3_GH080229',
#  'ds3_GH080234',
#  'ds3_GH080234',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090010',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH090234',
#  'ds3_GH100010',
#  'ds3_GH100010']

# %%
# for i, path in enumerate(lst, 0):
#     file_name = lst[i].split('/')[3].strip()
#     copyfile(path, './data_pothole/ds3_{}'.format(file_name))
